# %%
import pandas as pd

orth = pd.read_csv("data/orth.csv") 
original = pd.read_csv("data/original.csv") 
data = pd.read_csv("data/all_data_bcd_2019_10_01_after_QC.csv")
[i for i in original["species"] if i not in list(orth["species"])]
# Out:
# ['MEMB002F', 'MEMB004B', 'MEMB004E', 'MEMB005D', 'MEMB006A', 'MEMB006C']

# %%
data
# Out:
#           strand  align_position     score   region  enhancer_func   species  \
# 0       positive             972 -8.157841  VT14010              0  MEMB002A
# 1       positive             972 -0.436742  VT14010              0  MEMB002B
# 2       positive             972 -8.157841  VT14010              0  MEMB002C
# 3       positive             972  7.351161  VT14010              0  MEMB002D
# 4       positive             972  3.891729  VT14010              0  MEMB002E
# 5       positive             972 -0.436742  VT14010              0  MEMB002F
# 6       positive             972  7.351161  VT14010              0  MEMB003A
# 7       positive             972  7.351161  VT14010              0  MEMB003B
# 8       positive             972 -8.157841  VT14010              0  MEMB003C
# 9       positive             972  7.351161  VT14010              0  MEMB003D
# 10      positive             972  7.351161  VT14010              0  MEMB003F
# 11      positive             972 -0.436742  VT14010              0  MEMB004A
# 12      positive             972  7.351161  VT14010              0  MEMB004B
# 13      positive             972  7.351161  VT14010              0  MEMB004E
# 14      positive             972  7.351161  VT14010              0  MEMB005B
# 15      positive             972  7.351161  VT14010              0  MEMB005D
# 16      positive             972  7.351161  VT14010              0  MEMB006A
# 17      positive             972  7.351161  VT14010              0  MEMB006B
# 18      positive             972 -0.436742  VT14010              0  MEMB006C
# 19      positive             972 -8.157841  VT14010              0  MEMB007B
# 20      positive             972  7.351161  VT14010              0  MEMB007C
# 21      positive             972 -0.436742  VT14010              0  MEMB007D
# 22      positive             972  7.351161  VT14010              0  MEMB008C
# 23      positive             972  7.351161  VT14010              0      dkik
# 24      positive            1070 -0.436742  VT14010              0  MEMB002A
# 25      positive            1070 -0.436742  VT14010              0  MEMB002B
# 26      positive            1070 -0.436742  VT14010              0  MEMB002C
# 27      positive            1070  7.351161  VT14010              0  MEMB002D
# 28      positive            1070  7.351161  VT14010              0  MEMB002E
# 29      positive            1070 -0.436742  VT14010              0  MEMB002F
# ...          ...             ...       ...      ...            ...       ...
# 400122  positive            1096  3.891729  VT45977              1  MEMB006C
# 400123  positive            1096  3.891729  VT45977              1  MEMB007B
# 400124  positive            1096  3.891729  VT45977              1  MEMB007C
# 400125  positive            1096  7.351161  VT45977              1  MEMB007D
# 400126  positive            1096  3.891729  VT45977              1  MEMB008C
# 400127  positive            1096 -0.369939  VT45977              1      dkik
# 400128  negative            1984  3.089493  VT45977              1  MEMB002A
# 400129  negative            1984  3.089493  VT45977              1  MEMB002B
# 400130  negative            1984  3.089493  VT45977              1  MEMB002C
# 400131  negative            1984  3.089493  VT45977              1  MEMB002D
# 400132  negative            1984  3.089493  VT45977              1  MEMB002E
# 400133  negative            1984  3.089493  VT45977              1  MEMB002F
# 400134  negative            1984  3.089493  VT45977              1  MEMB003A
# 400135  negative            1984  3.089493  VT45977              1  MEMB003B
# 400136  negative            1984  3.089493  VT45977              1  MEMB003C
# 400137  negative            1984  3.089493  VT45977              1  MEMB003D
# 400138  negative            1984  3.089493  VT45977              1  MEMB003F
# 400139  negative            1984  3.089493  VT45977              1  MEMB004A
# 400140  negative            1984  3.089493  VT45977              1  MEMB004B
# 400141  negative            1984  3.089493  VT45977              1  MEMB004E
# 400142  negative            1984  3.089493  VT45977              1  MEMB005B
# 400143  negative            1984  3.089493  VT45977              1  MEMB005D
# 400144  negative            1984  3.089493  VT45977              1  MEMB006A
# 400145  negative            1984  3.089493  VT45977              1  MEMB006B
# 400146  negative            1984  3.089493  VT45977              1  MEMB006C
# 400147  negative            1984  3.089493  VT45977              1  MEMB007B
# 400148  negative            1984  3.089493  VT45977              1  MEMB007C
# 400149  negative            1984  7.351161  VT45977              1  MEMB007D
# 400150  negative            1984  3.089493  VT45977              1  MEMB008C
# 400151  negative            1984  3.089493  VT45977              1      dkik
#
#         raw_position raw_seq before_seq after_seq TFBS_called
# 0                376  CAACCT     AATTGC    AGCAAT          no
# 1                375  CAATCT     AATTGC    AGCAAT          no
# 2                376  CAACCT     AATTGC    AGCAAT          no
# 3                376  TAATCT     AATTGC    AGCAAT         yes
# 4                376  TAATCG     AATAGC    AGCTAT          no
# 5                376  CAATCT     AATTGC    AGCTAT          no
# 6                376  TAATCT     AATTGC    GGCAAT         yes
# 7                377  TAATCT     AATTGC    AGCTAT         yes
# 8                376  CAACCT     AATTGC    AGCAAT          no
# 9                376  TAATCT     AATTGC    GGCAAT         yes
# 10               376  TAATCT     GATTGC    GGCAAT         yes
# 11               375  CAATCT     AATTGC    AGCAAT          no
# 12               376  TAATCT     AATTGC    AGCGAT         yes
# 13               379  TAATCT     AATTGC    AGCGAT         yes
# 14               376  TAATCT     AATTGC    AGCGAT         yes
# 15               376  TAATCT     AATCGC    AGCGAT         yes
# 16               375  TAATCT     AATCGC    AGCGAT         yes
# 17               376  TAATCT     AATTGC    AGCTAT         yes
# 18               376  CAATCT     AATTGC    AGCGAT          no
# 19               376  CAACCT     AATTGC    AGCAAT          no
# 20               966  TAATCT     AATTGC    AGCTAT         yes
# 21               379  CAATCT     AATTGC    AGCGAT          no
# 22               376  TAATCT     AATTGC    AGCGAT         yes
# 23               376  TAATCT     AATTGC    GGCAAT         yes
# 24               474  TAAGAC     ACGTCA    GCCTTA          no
# 25               473  TAAGAC     AAGTCA    GCCTTA          no
# 26               474  TAAGAC     ACGTCA    GCCTTA          no
# 27               474  TAAGCC     ATGTCA    GCCTTA         yes
# 28               474  TAAGCC     ACGTCA    GCCTTA         yes
# 29               474  TAAGAC     AAGTCA    GCCTTA          no
# ...              ...     ...        ...       ...         ...
# 400122           621  TAAACC     AGACTT    ATTTAG          no
# 400123           546  TAAACC     AGGATT    ATTTAG          no
# 400124           521  TAAACC     AGAATT    ATTTAA          no
# 400125           535  TAAGCC     AGAATT    ATTTAG         yes
# 400126           875  TAAACC     AGAATT    ATTTAG          no
# 400127           934  TAAGCG     AGAATT    ATTTAG          no
# 400128          1248  TAAGCT     TAATTC    AGCAGT          no
# 400129          1619  TAAGCT     TAATTC    CGCAGT          no
# 400130          1626  TAAGCT     TAATTC    AGCAGT          no
# 400131          1263  TAAGCT     TAATTC    CGCACT          no
# 400132          1345  TAAGCT     TAATTC    CGCAGT          no
# 400133          1313  TAAGCT     TAATTC    AGCAGT          no
# 400134          1684  TAAGCT     TAATTC    CGCAGT          no
# 400135          1280  TAAGCT     TAATTC    CGCAGT          no
# 400136          1307  TAAGCT     TAATTC    AGCAGT          no
# 400137          1314  TAAGCT     TAATTC    CGCAGT          no
# 400138           977  TAAGCT     TAATTC    AGCAGT          no
# 400139          1596  TAAGCT     TAATTC    CGCAGT          no
# 400140          1264  TAAGCT     TAATTC    CGCAGT          no
# 400141          1273  TAAGCT     TAATTC    CGCAGT          no
# 400142          1239  TAAGCT     TAATTC    CGCAGT          no
# 400143          1379  TAAGCT     TAATTC    CGCAGT          no
# 400144          1304  TAAGCT     TAATTC    CGCAGT          no
# 400145          1254  TAAGCT     TAATTC    CGCTGT          no
# 400146          1377  TAAGCT     TAATTC    CGCAGT          no
# 400147          1258  TAAGCT     TAATTC    AGCAGT          no
# 400148          1266  TAAGCT     TAATTC    CGCAGT          no
# 400149          1273  TAAGCC     TAATTC    CGTAGT         yes
# 400150          1607  TAAGCT     TAATTC    CGCAGT          no
# 400151          1685  TAAGCT     TAATTC    CGCAGT          no
#
# [400152 rows x 11 columns]

# %%
unique_regions = data["region"].unique()
len(unique_regions)
# Out:
# 2264

# %%
not_included = {}
for region in unique_regions:
    temp = data[data["region"] == region]
    temp_tfbs = temp[data["TFBS_called"] == "yes"]
    orth = temp_tfbs["species"].unique()
    original = temp["species"].unique()
#     print(len(orth))
#     print(len(original))
    for i in original:
        if i not in orth:
            if i not in not_included:
                not_included[i] = 0
            else:
                not_included[i] += 1
# Out:
# C:\Users\zliu1\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
sorted(not_included.items(), key=lambda kv: kv[1])
# Out:
# [('MEMB006B', 405),
#  ('MEMB003B', 410),
#  ('MEMB007C', 416),
#  ('MEMB006A', 420),
#  ('MEMB002D', 427),
#  ('MEMB002E', 431),
#  ('MEMB003D', 433),
#  ('MEMB003F', 433),
#  ('MEMB004B', 434),
#  ('MEMB005D', 434),
#  ('MEMB005B', 437),
#  ('MEMB003A', 438),
#  ('MEMB007D', 440),
#  ('dkik', 440),
#  ('MEMB006C', 443),
#  ('MEMB002B', 445),
#  ('MEMB004E', 445),
#  ('MEMB008C', 456),
#  ('MEMB002C', 457),
#  ('MEMB007B', 460),
#  ('MEMB004A', 464),
#  ('MEMB002A', 466),
#  ('MEMB003C', 473),
#  ('MEMB002F', 478)]
